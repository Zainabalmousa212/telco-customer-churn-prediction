# %% [markdown]
# # Churn Model Testing Notebook
#
# This notebook loads the saved churn model and tests predictions on new customer data.

# %%
# Step 1: Load libraries and model
import joblib
import pandas as pd

model = joblib.load('churn_model_pipeline.joblib')
print('Model loaded successfully')
# Out:
# Model loaded successfully

# %%
# Step 2: Create a new customer example
new_customer = pd.DataFrame({
    'gender': ['Female'],
    'SeniorCitizen': [0],
    'Partner': ['Yes'],
    'Dependents': ['No'],
    'tenure': [12],
    'PhoneService': ['Yes'],
    'MultipleLines': ['No'],
    'InternetService': ['Fiber optic'],
    'OnlineSecurity': ['No'],
    'OnlineBackup': ['Yes'],
    'DeviceProtection': ['No'],
    'TechSupport': ['No'],
    'StreamingTV': ['Yes'],
    'StreamingMovies': ['Yes'],
    'Contract': ['Month-to-month'],
    'PaperlessBilling': ['Yes'],
    'PaymentMethod': ['Electronic check'],
    'MonthlyCharges': [75.5],
    'TotalCharges': [906]
})

new_customer
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No      12          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No     Fiber optic             No          Yes               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No         Yes             Yes  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges
# 0  Electronic check            75.5           906

# %%
# Step 3: Make prediction
prediction = model.predict(new_customer)

if prediction[0] == 1:
    print('Prediction: Customer WILL churn')
else:
    print('Prediction: Customer will NOT churn')
# Out:
# Prediction: Customer WILL churn

# %%
# Step 4: Show probability
probability = model.predict_proba(new_customer)

print(f'Probability of staying: {probability[0][0]:.2f}')
print(f'Probability of churn: {probability[0][1]:.2f}')
# Out:
# Probability of staying: 0.47
# Probability of churn: 0.54
